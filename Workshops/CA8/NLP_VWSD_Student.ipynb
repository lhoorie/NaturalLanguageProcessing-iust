# %% [markdown]
# # Prerequisite

# %% [markdown]
# ## Install requirements

# %%
# !pip install accelerate transformers datasets[vision] evaluate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting accelerate
#   Downloading accelerate-0.19.0-py3-none-any.whl (219 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.1/219.1 kB 5.0 MB/s eta 0:00:00
# Collecting transformers
#   Downloading transformers-4.29.2-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 78.2 MB/s eta 0:00:00
# Collecting datasets[vision]
#   Downloading datasets-2.12.0-py3-none-any.whl (474 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 26.1 MB/s eta 0:00:00
# Collecting evaluate
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.0.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 14.2 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 60.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets[vision]) (9.0.0)
# Collecting dill<0.3.7,>=0.3.0 (from datasets[vision])
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets[vision]) (1.5.3)
# Collecting xxhash (from datasets[vision])
#   Downloading xxhash-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 3.7 MB/s eta 0:00:00
# Collecting multiprocess (from datasets[vision])
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 17.4 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets[vision]) (2023.4.0)
# Collecting aiohttp (from datasets[vision])
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 70.6 MB/s eta 0:00:00
# Collecting responses<0.19 (from datasets[vision])
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=6.2.1 in /usr/local/lib/python3.10/dist-packages (from datasets[vision]) (8.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]) (2.0.12)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets[vision])
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 15.5 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->datasets[vision])
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets[vision])
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 25.0 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets[vision])
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 18.0 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets[vision])
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->accelerate) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->accelerate) (16.0.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets[vision]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets[vision]) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets[vision]) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->accelerate) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->accelerate) (1.3.0)
# Installing collected packages: tokenizers, xxhash, multidict, frozenlist, dill, async-timeout, yarl, responses, multiprocess, huggingface-hub, aiosignal, transformers, aiohttp, datasets, evaluate, accelerate
# Successfully installed accelerate-0.19.0 aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.12.0 dill-0.3.6 evaluate-0.4.0 frozenlist-1.3.3 huggingface-hub-0.14.1 multidict-6.0.4 multiprocess-0.70.14 responses-0.18.0 tokenizers-0.13.3 transformers-4.29.2 xxhash-3.2.0 yarl-1.9.2

# %% [markdown]
# ## Import requirements

# %%
from tqdm import tqdm
import gc
import os
import shutil
import glob
import random
import numpy as np
import torch
from torch import nn
import pandas as pd
from PIL import Image as PIL_Image
from PIL import ImageFile

from dataclasses import dataclass
from typing import Optional, Tuple, Union

import evaluate


from datasets import Dataset, Features, Value, Image, ClassLabel, concatenate_datasets
from transformers import AltCLIPProcessor, AltCLIPModel
from transformers.configuration_utils import PretrainedConfig
from transformers.models.altclip.modeling_altclip import AltCLIPEncoderLayer
from transformers.modeling_utils import PreTrainedModel
from transformers.modeling_outputs import BaseModelOutput, ModelOutput
from transformers import TrainingArguments, Trainer

# %% [markdown]
# ## Set some parameters to have determinism

# %%
ImageFile.LOAD_TRUNCATED_IMAGES = True
PIL_Image.MAX_IMAGE_PIXELS = 933120000

GLOBAL_SEED = 10

np.random.seed(GLOBAL_SEED)
random.seed(GLOBAL_SEED)
torch.manual_seed(GLOBAL_SEED)
torch.use_deterministic_algorithms(True)
# %env CUBLAS_WORKSPACE_CONFIG=:4096:8
# Out:
# env: CUBLAS_WORKSPACE_CONFIG=:4096:8

# %% [markdown]
# # Prepare data

# %% [markdown]
# ## Download

# %%
# !wget -O train_trial.zip -c 'https://docs.google.com/uc?export=download&id=1byX4wpe1UjyCVyYrT04sW17NnycKAK7N&confirm=t'
# !wget -O test_images.zip -c 'https://docs.google.com/uc?export=download&id=1rK7EskkEXzD59j5On-8orO5mIinQGUMW&confirm=t'
# !wget -O test_data.zip -c 'https://docs.google.com/uc?export=download&id=10vDZsY0EhzvFFR8IF-3P_2ApOF0GIMML&confirm=t'
# Out:
# --2023-05-17 17:05:12--  https://docs.google.com/uc?export=download&id=1byX4wpe1UjyCVyYrT04sW17NnycKAK7N&confirm=t
# Resolving docs.google.com (docs.google.com)... 108.177.119.101, 108.177.119.102, 108.177.119.113, ...
# Connecting to docs.google.com (docs.google.com)|108.177.119.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-08-48-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/5gv2fn36r8uo6o6m0g9ep017lmdakpot/1684343100000/04589392675467887255/*/1byX4wpe1UjyCVyYrT04sW17NnycKAK7N?e=download&uuid=71b544f6-20ca-476e-aa81-5661e2715173 [following]
# Warning: wildcards not supported in HTTP.
# --2023-05-17 17:05:13--  https://doc-08-48-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/5gv2fn36r8uo6o6m0g9ep017lmdakpot/1684343100000/04589392675467887255/*/1byX4wpe1UjyCVyYrT04sW17NnycKAK7N?e=download&uuid=71b544f6-20ca-476e-aa81-5661e2715173
# Resolving doc-08-48-docs.googleusercontent.com (doc-08-48-docs.googleusercontent.com)... 108.177.126.132, 2a00:1450:4013:c01::84
# Connecting to doc-08-48-docs.googleusercontent.com (doc-08-48-docs.googleusercontent.com)|108.177.126.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18353852513 (17G) [application/zip]
# Saving to: ‘train_trial.zip’
#
# train_trial.zip     100%[===================>]  17.09G   176MB/s    in 2m 19s
#
# 2023-05-17 17:07:32 (126 MB/s) - ‘train_trial.zip’ saved [18353852513/18353852513]
#
# --2023-05-17 17:07:32--  https://docs.google.com/uc?export=download&id=1rK7EskkEXzD59j5On-8orO5mIinQGUMW&confirm=t
# Resolving docs.google.com (docs.google.com)... 108.177.126.102, 108.177.126.101, 108.177.126.100, ...
# Connecting to docs.google.com (docs.google.com)|108.177.126.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-14-48-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/0906it7fj9kevmf5jka3mch8el547hke/1684343250000/04589392675467887255/*/1rK7EskkEXzD59j5On-8orO5mIinQGUMW?e=download&uuid=33da0826-aef0-46e6-9ae6-f9f9c9f8783c [following]
# Warning: wildcards not supported in HTTP.
# --2023-05-17 17:07:33--  https://doc-14-48-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/0906it7fj9kevmf5jka3mch8el547hke/1684343250000/04589392675467887255/*/1rK7EskkEXzD59j5On-8orO5mIinQGUMW?e=download&uuid=33da0826-aef0-46e6-9ae6-f9f9c9f8783c
# Resolving doc-14-48-docs.googleusercontent.com (doc-14-48-docs.googleusercontent.com)... 108.177.126.132, 2a00:1450:4013:c01::84
# Connecting to doc-14-48-docs.googleusercontent.com (doc-14-48-docs.googleusercontent.com)|108.177.126.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10380900253 (9.7G) [application/zip]
# Saving to: ‘test_images.zip’
#
# test_images.zip     100%[===================>]   9.67G   105MB/s    in 85s
#
# 2023-05-17 17:08:58 (117 MB/s) - ‘test_images.zip’ saved [10380900253/10380900253]
#
# --2023-05-17 17:08:58--  https://docs.google.com/uc?export=download&id=10vDZsY0EhzvFFR8IF-3P_2ApOF0GIMML&confirm=t
# Resolving docs.google.com (docs.google.com)... 108.177.119.102, 108.177.119.138, 108.177.119.113, ...
# Connecting to docs.google.com (docs.google.com)|108.177.119.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0o-48-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/u4ch16980jjaqo1pd97kv51hoi1prn00/1684343325000/04589392675467887255/*/10vDZsY0EhzvFFR8IF-3P_2ApOF0GIMML?e=download&uuid=50c55f0a-2d31-4ff7-80d9-1e5f49c706d8 [following]
# Warning: wildcards not supported in HTTP.
# --2023-05-17 17:08:58--  https://doc-0o-48-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/u4ch16980jjaqo1pd97kv51hoi1prn00/1684343325000/04589392675467887255/*/10vDZsY0EhzvFFR8IF-3P_2ApOF0GIMML?e=download&uuid=50c55f0a-2d31-4ff7-80d9-1e5f49c706d8
# Resolving doc-0o-48-docs.googleusercontent.com (doc-0o-48-docs.googleusercontent.com)... 108.177.126.132, 2a00:1450:4013:c01::84
# Connecting to doc-0o-48-docs.googleusercontent.com (doc-0o-48-docs.googleusercontent.com)|108.177.126.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36754 (36K) [application/zip]
# Saving to: ‘test_data.zip’
#
# test_data.zip       100%[===================>]  35.89K  --.-KB/s    in 0.001s
#
# 2023-05-17 17:08:59 (65.3 MB/s) - ‘test_data.zip’ saved [36754/36754]

# %% [markdown]
# ## Unzip and unify file names for convenience (Ignore disk warning)

# %%
# !unzip train_trial.zip
# !rm train_trial.zip
# !unzip test_images.zip
# !rm test_images.zip
# !unzip test_data.zip -d test_data
# !rm test_data.zip
# !mkdir semeval-2023-task-1-V-WSD-train-v1/test_v1
# !mv test_data/en.test.data.v1.1.txt semeval-2023-task-1-V-WSD-train-v1/test_v1/en.test.data.v1.txt
# !mv test_data/en.test.gold.v1.1.txt semeval-2023-task-1-V-WSD-train-v1/test_v1/en.test.gold.v1.txt
# !mv test_data/it.test.data.v1.1.txt semeval-2023-task-1-V-WSD-train-v1/test_v1/it.test.data.v1.txt
# !mv test_data/it.test.gold.v1.1.txt semeval-2023-task-1-V-WSD-train-v1/test_v1/it.test.gold.v1.txt
# !mv test_data/fa.test.data.txt semeval-2023-task-1-V-WSD-train-v1/test_v1/fa.test.data.v1.txt
# !mv test_data/fa.test.gold.txt semeval-2023-task-1-V-WSD-train-v1/test_v1/fa.test.gold.v1.txt
# !rm -r test_data
# !mv test_images semeval-2023-task-1-V-WSD-train-v1/test_v1/test_images_v1
# !mv semeval-2023-task-1-V-WSD-train-v1 semeval-2023-task-1-V-WSD-v1
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: test_images/image.3796.jpg
#   inflating: test_images/image.3797.jpg
#  extracting: test_images/image.3798.png
#   inflating: test_images/image.3799.jpg
#   inflating: test_images/image.38.jpg
#   inflating: test_images/image.380.jpg
#   inflating: test_images/image.3800.jpg
#   inflating: test_images/image.3801.jpg
#   inflating: test_images/image.3802.png
#   inflating: test_images/image.3803.jpg
#   inflating: test_images/image.3804.jpg
#   inflating: test_images/image.3805.jpg
#   inflating: test_images/image.3806.jpg
#   inflating: test_images/image.3807.jpg
#   inflating: test_images/image.3808.jpg
#   inflating: test_images/image.3809.jpg
#  extracting: test_images/image.381.PNG
#   inflating: test_images/image.3810.jpg
#   inflating: test_images/image.3811.jpg
#   inflating: test_images/image.3812.jpg
#   inflating: test_images/image.3813.jpg
#   inflating: test_images/image.3814.jpg
#   inflating: test_images/image.3815.jpg
#   inflating: test_images/image.3816.jpg
#   inflating: test_images/image.3817.jpg
#   inflating: test_images/image.3818.jpg
#   inflating: test_images/image.3819.jpg
#   inflating: test_images/image.382.jpg
#   inflating: test_images/image.3820.jpg
#   inflating: test_images/image.3821.jpg
#   inflating: test_images/image.3822.jpg
#   inflating: test_images/image.3823.jpg
#   inflating: test_images/image.3824.jpg
#   inflating: test_images/image.3825.jpg
#   inflating: test_images/image.3826.jpg
#   inflating: test_images/image.3827.jpg
#   inflating: test_images/image.3828.jpg
#   inflating: test_images/image.3829.jpg
#   inflating: test_images/image.383.jpg
#   inflating: test_images/image.3830.jpg
#   inflating: test_images/image.3831.png
#   inflating: test_images/image.3832.jpg
#   inflating: test_images/image.3833.jpg
#   inflating: test_images/image.3834.jpg
#   inflating: test_images/image.3835.jpg
#   inflating: test_images/image.3836.jpg
#   inflating: test_images/image.3837.jpg
#   inflating: test_images/image.3838.jpg
#   inflating: test_images/image.3839.jpg
#   inflating: test_images/image.384.jpg
#   inflating: test_images/image.3840.jpg
#   inflating: test_images/image.3841.jpg
#   inflating: test_images/image.3842.jpg
#   inflating: test_images/image.3843.jpg
#   inflating: test_images/image.3844.jpg
#  extracting: test_images/image.3845.jpg
#   inflating: test_images/image.3846.jpg
#   inflating: test_images/image.3847.jpg
#   inflating: test_images/image.3848.jpg
#   inflating: test_images/image.3849.jpg
#   inflating: test_images/image.385.jpg
#   inflating: test_images/image.3850.jpg
#   inflating: test_images/image.3851.jpg
#   inflating: test_images/image.3852.jpg
#   inflating: test_images/image.3853.jpg
#   inflating: test_images/image.3854.jpg
#   inflating: test_images/image.3855.jpg
#   inflating: test_images/image.3856.jpg
#   inflating: test_images/image.3857.jpg
#   inflating: test_images/image.3858.png
#   inflating: test_images/image.3859.jpg
#   inflating: test_images/image.386.jpg
#  extracting: test_images/image.3860.png
#   inflating: test_images/image.3861.jpg
#  extracting: test_images/image.3862.png
#   inflating: test_images/image.3863.jpg
#   inflating: test_images/image.3864.jpg
#   inflating: test_images/image.3865.jpg
#   inflating: test_images/image.3866.png
#  extracting: test_images/image.3867.jpg
#   inflating: test_images/image.3868.jpg
#   inflating: test_images/image.3869.jpg
#   inflating: test_images/image.387.jpg
#  extracting: test_images/image.3870.png
#   inflating: test_images/image.3871.png
#   inflating: test_images/image.3872.png
#   inflating: test_images/image.3873.jpg
#   inflating: test_images/image.3874.png
#   inflating: test_images/image.3875.png
#   inflating: test_images/image.3876.png
#   inflating: test_images/image.3877.jpg
#   inflating: test_images/image.3878.jpg
#   inflating: test_images/image.3879.jpg
#   inflating: test_images/image.388.jpg
#   inflating: test_images/image.3880.jpg
#   inflating: test_images/image.3881.jpg
#   inflating: test_images/image.3882.jpg
#   inflating: test_images/image.3883.jpg
#   inflating: test_images/image.3884.jpg
#   inflating: test_images/image.3885.jpg
#   inflating: test_images/image.3886.jpg
#   inflating: test_images/image.3887.jpg
#   inflating: test_images/image.3888.jpg
#   inflating: test_images/image.3889.png
#   inflating: test_images/image.389.jpg
#   inflating: test_images/image.3890.jpg
#   inflating: test_images/image.3891.jpg
#   inflating: test_images/image.3892.png
#   inflating: test_images/image.3893.png
#   inflating: test_images/image.3894.png
#   inflating: test_images/image.3895.png
#   inflating: test_images/image.3896.png
#   inflating: test_images/image.3897.jpg
#   inflating: test_images/image.3898.png
#   inflating: test_images/image.3899.jpg
#   inflating: test_images/image.39.jpg
#   inflating: test_images/image.390.jpg
#   inflating: test_images/image.3900.jpg
#   inflating: test_images/image.3901.jpg
#   inflating: test_images/image.3902.png
#   inflating: test_images/image.3903.jpg
#   inflating: test_images/image.3904.jpg
#   inflating: test_images/image.3905.png
#   inflating: test_images/image.3906.jpg
#   inflating: test_images/image.3907.jpg
#   inflating: test_images/image.3908.jpg
#   inflating: test_images/image.3909.jpg
#   inflating: test_images/image.391.jpg
#   inflating: test_images/image.3910.jpg
#   inflating: test_images/image.3911.jpg
#   inflating: test_images/image.3912.jpg
#   inflating: test_images/image.3913.JPG
#   inflating: test_images/image.3914.jpg
#   inflating: test_images/image.3915.jpg
#   inflating: test_images/image.3916.jpg
#   inflating: test_images/image.3917.jpg
#   inflating: test_images/image.3918.jpg
#   inflating: test_images/image.3919.jpg
#   inflating: test_images/image.392.jpg
#   inflating: test_images/image.3920.jpg
#  extracting: test_images/image.3921.png
#   inflating: test_images/image.3922.jpg
#   inflating: test_images/image.3923.jpg
#   inflating: test_images/image.3924.png
#   inflating: test_images/image.3925.jpg
#  extracting: test_images/image.3926.jpg
#   inflating: test_images/image.3927.jpg
#   inflating: test_images/image.3928.jpg
#   inflating: test_images/image.3929.png
#   inflating: test_images/image.393.jpg
#   inflating: test_images/image.3930.jpg
#   inflating: test_images/image.3931.jpg
#   inflating: test_images/image.3932.jpg
#   inflating: test_images/image.3933.jpg
#   inflating: test_images/image.3934.jpg
#   inflating: test_images/image.3935.jpg
#   inflating: test_images/image.3936.jpg
#   inflating: test_images/image.3937.jpg
#   inflating: test_images/image.3938.jpg
#   inflating: test_images/image.3939.jpg
#   inflating: test_images/image.394.jpg
#   inflating: test_images/image.3940.jpg
#   inflating: test_images/image.3941.jpg
#   inflating: test_images/image.3942.jpg
#   inflating: test_images/image.3943.jpg
#   inflating: test_images/image.3944.jpg
#   inflating: test_images/image.3945.jpg
#   inflating: test_images/image.3946.jpg
#   inflating: test_images/image.3947.jpg
#   inflating: test_images/image.3948.jpg
#   inflating: test_images/image.3949.jpg
#   inflating: test_images/image.395.jpg
#   inflating: test_images/image.3950.jpg
#   inflating: test_images/image.3951.jpg
#   inflating: test_images/image.3952.jpg
#   inflating: test_images/image.3953.jpg
#   inflating: test_images/image.3954.jpg
#   inflating: test_images/image.3955.jpg
#   inflating: test_images/image.3956.jpg
#   inflating: test_images/image.3957.png
#   inflating: test_images/image.3958.jpg
#   inflating: test_images/image.3959.jpg
#   inflating: test_images/image.396.jpg
#   inflating: test_images/image.3960.jpg
#   inflating: test_images/image.3961.jpg
#   inflating: test_images/image.3962.jpg
#   inflating: test_images/image.3963.jpg
#   inflating: test_images/image.3964.jpg
#   inflating: test_images/image.3965.png
#   inflating: test_images/image.3966.jpg
#   inflating: test_images/image.3967.jpg
#   inflating: test_images/image.3968.jpg
#   inflating: test_images/image.3969.jpg
#   inflating: test_images/image.397.jpg
#   inflating: test_images/image.3970.jpg
#   inflating: test_images/image.3971.jpg
#   inflating: test_images/image.3972.jpg
#   inflating: test_images/image.3973.jpg
#   inflating: test_images/image.3974.jpg
#   inflating: test_images/image.3975.jpg
#   inflating: test_images/image.3976.jpg
#   inflating: test_images/image.3977.jpg
#   inflating: test_images/image.3978.jpg
#   inflating: test_images/image.3979.jpg
#   inflating: test_images/image.398.jpg
#   inflating: test_images/image.3980.jpg
#   inflating: test_images/image.3981.png
#   inflating: test_images/image.3982.jpg
#   inflating: test_images/image.3983.png
#   inflating: test_images/image.3984.png
#   inflating: test_images/image.3985.jpg
#   inflating: test_images/image.3986.jpg
#   inflating: test_images/image.3987.jpg
#   inflating: test_images/image.3988.jpg
#   inflating: test_images/image.3989.jpg
#   inflating: test_images/image.399.jpg
#   inflating: test_images/image.3990.jpg
#   inflating: test_images/image.3991.jpg
#   inflating: test_images/image.3992.jpg
#  extracting: test_images/image.3993.jpg
#   inflating: test_images/image.3994.jpg
#   inflating: test_images/image.3995.jpg
#   inflating: test_images/image.3996.jpg
#  extracting: test_images/image.3997.jpg
#   inflating: test_images/image.3998.jpg
#   inflating: test_images/image.3999.jpg
#   inflating: test_images/image.4.jpg
#   inflating: test_images/image.40.jpg
#   inflating: test_images/image.400.jpg
#   inflating: test_images/image.4000.jpg
#   inflating: test_images/image.4001.png
#   inflating: test_images/image.4002.jpg
#   inflating: test_images/image.4003.jpg
#   inflating: test_images/image.4004.jpg
#   inflating: test_images/image.4005.jpg
#   inflating: test_images/image.4006.jpg
#   inflating: test_images/image.4007.jpg
#   inflating: test_images/image.4008.jpg
#   inflating: test_images/image.4009.jpg
#   inflating: test_images/image.401.jpg
#   inflating: test_images/image.4010.png
#   inflating: test_images/image.4011.jpg
#   inflating: test_images/image.4012.jpg
#  extracting: test_images/image.4013.jpg
#   inflating: test_images/image.4014.jpg
#   inflating: test_images/image.4015.jpg
#   inflating: test_images/image.4016.jpg
#   inflating: test_images/image.4017.jpg
#   inflating: test_images/image.4018.jpg
#   inflating: test_images/image.4019.jpg
#   inflating: test_images/image.402.jpg
#   inflating: test_images/image.4020.jpg
#   inflating: test_images/image.4021.png
#  extracting: test_images/image.4022.jpg
#   inflating: test_images/image.4023.png
#   inflating: test_images/image.4024.jpg
#   inflating: test_images/image.4025.jpg
#   inflating: test_images/image.4026.jpg
#   inflating: test_images/image.4027.jpg
#   inflating: test_images/image.4028.png
#   inflating: test_images/image.4029.jpg
#   inflating: test_images/image.403.jpg
#   inflating: test_images/image.4030.jpg
#   inflating: test_images/image.4031.jpg
#  extracting: test_images/image.4032.jpg
#   inflating: test_images/image.4033.jpg
#   inflating: test_images/image.4034.jpg
#   inflating: test_images/image.4035.jpg
#   inflating: test_images/image.4036.jpg
#   inflating: test_images/image.4037.jpg
#   inflating: test_images/image.4038.jpg
#   inflating: test_images/image.4039.jpg
#   inflating: test_images/image.404.jpg
#  extracting: test_images/image.4040.jpeg
#   inflating: test_images/image.4041.jpg
#   inflating: test_images/image.4042.jpg
#  extracting: test_images/image.4043.png
#   inflating: test_images/image.4044.jpg
#   inflating: test_images/image.4045.jpg
#   inflating: test_images/image.4046.jpg
#   inflating: test_images/image.4047.jpg
#   inflating: test_images/image.4048.jpg
#   inflating: test_images/image.4049.jpg
#   inflating: test_images/image.405.jpg
#   inflating: test_images/image.4050.jpg
#   inflating: test_images/image.4051.jpg
#   inflating: test_images/image.4052.jpg
#   inflating: test_images/image.4053.jpg
#   inflating: test_images/image.4054.jpg
#   inflating: test_images/image.4055.jpg
#   inflating: test_images/image.4056.jpg
#   inflating: test_images/image.4057.jpg
#   inflating: test_images/image.4058.jpg
#  extracting: test_images/image.4059.jpg
#   inflating: test_images/image.406.jpg
#   inflating: test_images/image.4060.jpg
#   inflating: test_images/image.4061.jpg
#   inflating: test_images/image.4062.jpg
#   inflating: test_images/image.4063.jpg
#   inflating: test_images/image.4064.jpg
#   inflating: test_images/image.4065.jpg
#   inflating: test_images/image.4066.jpg
#   inflating: test_images/image.4067.jpg
#   inflating: test_images/image.4068.jpg
#   inflating: test_images/image.4069.jpg
#   inflating: test_images/image.407.jpg
#   inflating: test_images/image.4070.jpg
#   inflating: test_images/image.4071.jpg
#   inflating: test_images/image.4072.jpg
#   inflating: test_images/image.4073.jpg
#   inflating: test_images/image.4074.jpg
#   inflating: test_images/image.4075.jpg
#   inflating: test_images/image.4076.jpg
#   inflating: test_images/image.4077.jpg
#   inflating: test_images/image.4078.jpg
#   inflating: test_images/image.4079.jpg
#   inflating: test_images/image.408.jpg
#   inflating: test_images/image.4080.jpg
#   inflating: test_images/image.4081.jpg
#   inflating: test_images/image.4082.jpg
#   inflating: test_images/image.4083.jpg
#   inflating: test_images/image.4084.jpg
#   inflating: test_images/image.4085.png
#   inflating: test_images/image.4086.jpg
#   inflating: test_images/image.4087.jpg
#   inflating: test_images/image.4088.jpg
#   inflating: test_images/image.4089.png
#   inflating: test_images/image.409.jpg
#   inflating: test_images/image.4090.png
#   inflating: test_images/image.4091.jpg
#   inflating: test_images/image.4092.png
#   inflating: test_images/image.4093.jpg
#   inflating: test_images/image.4094.jpg
#   inflating: test_images/image.4095.jpg
#   inflating: test_images/image.4096.jpg
#   inflating: test_images/image.4097.jpg
#   inflating: test_images/image.4098.jpg
#   inflating: test_images/image.4099.jpg
#   inflating: test_images/image.41.jpg
#   inflating: test_images/image.410.jpg
#   inflating: test_images/image.4100.jpg
#   inflating: test_images/image.4101.jpg
#   inflating: test_images/image.4102.jpg
#   inflating: test_images/image.4103.jpg
#   inflating: test_images/image.4104.jpg
#   inflating: test_images/image.4105.jpg
#   inflating: test_images/image.4106.jpg
#   inflating: test_images/image.4107.jpg
#   inflating: test_images/image.4108.jpg
#   inflating: test_images/image.4109.jpg
#   inflating: test_images/image.411.jpg
#   inflating: test_images/image.4110.jpg
#   inflating: test_images/image.4111.jpg
#   inflating: test_images/image.4112.jpg
#  extracting: test_images/image.4113.jpg
#   inflating: test_images/image.4114.jpg
#   inflating: test_images/image.4115.jpg
#   inflating: test_images/image.4116.jpg
#   inflating: test_images/image.4117.jpg
#   inflating: test_images/image.4118.png
#   inflating: test_images/image.4119.jpg
#   inflating: test_images/image.412.jpg
#   inflating: test_images/image.4120.jpg
#   inflating: test_images/image.4121.jpg
#   inflating: test_images/image.4122.jpg
#   inflating: test_images/image.4123.jpg
#   inflating: test_images/image.4124.jpg
#   inflating: test_images/image.4125.jpg
#   inflating: test_images/image.4126.jpg
#   inflating: test_images/image.4127.jpg
#   inflating: test_images/image.4128.jpg
#   inflating: test_images/image.4129.jpg
#   inflating: test_images/image.413.jpg
#   inflating: test_images/image.4130.jpg
#   inflating: test_images/image.4131.jpg
#   inflating: test_images/image.4132.jpg
#   inflating: test_images/image.4133.jpg
#   inflating: test_images/image.4134.jpg
#   inflating: test_images/image.4135.jpg
#   inflating: test_images/image.4136.jpg
#   inflating: test_images/image.4137.jpg
#   inflating: test_images/image.4138.jpg
#   inflating: test_images/image.4139.jpg
#   inflating: test_images/image.414.jpg
#  extracting: test_images/image.4140.jpg
#   inflating: test_images/image.4141.jpg
#   inflating: test_images/image.4142.jpg
#   inflating: test_images/image.4143.jpg
#   inflating: test_images/image.4144.jpg
#   inflating: test_images/image.4145.jpg
#   inflating: test_images/image.4146.jpg
#   inflating: test_images/image.4147.png
#   inflating: test_images/image.4148.jpg
#   inflating: test_images/image.4149.jpg
#   inflating: test_images/image.415.jpg
#   inflating: test_images/image.4150.jpg
#   inflating: test_images/image.4151.jpg
#   inflating: test_images/image.4152.jpg
#   inflating: test_images/image.4153.jpg
#   inflating: test_images/image.4154.jpg
#   inflating: test_images/image.4155.jpg
#   inflating: test_images/image.4156.jpg
#   inflating: test_images/image.4157.jpg
#   inflating: test_images/image.4158.jpg
#   inflating: test_images/image.4159.jpg
#   inflating: test_images/image.416.jpg
#   inflating: test_images/image.4160.jpg
#   inflating: test_images/image.4161.jpg
#   inflating: test_images/image.4162.jpg
#   inflating: test_images/image.4163.jpg
#   inflating: test_images/image.4164.jpg
#   inflating: test_images/image.4165.jpg
#   inflating: test_images/image.4166.jpg
#   inflating: test_images/image.4167.jpg
#   inflating: test_images/image.4168.jpg
#   inflating: test_images/image.4169.jpg
#   inflating: test_images/image.417.jpg
#   inflating: test_images/image.4170.png
#   inflating: test_images/image.4171.jpg
#   inflating: test_images/image.4172.jpg
#  extracting: test_images/image.4173.jpg
#   inflating: test_images/image.4174.jpg
#   inflating: test_images/image.4175.jpg
#   inflating: test_images/image.4176.jpg
#   inflating: test_images/image.4177.png
#   inflating: test_images/image.4178.jpg
#   inflating: test_images/image.4179.jpg
#   inflating: test_images/image.418.jpg
#   inflating: test_images/image.4180.jpg
#   inflating: test_images/image.4181.png
#   inflating: test_images/image.4182.jpg
#   inflating: test_images/image.4183.jpg
#  extracting: test_images/image.4184.jpg
#   inflating: test_images/image.4185.jpg
#   inflating: test_images/image.4186.jpg
#   inflating: test_images/image.4187.jpg
#   inflating: test_images/image.4188.jpg
#   inflating: test_images/image.4189.jpg
#   inflating: test_images/image.419.jpg
#   inflating: test_images/image.4190.jpg
#   inflating: test_images/image.4191.jpg
#   inflating: test_images/image.4192.jpg
#   inflating: test_images/image.4193.jpg
#   inflating: test_images/image.4194.jpg
#   inflating: test_images/image.4195.png
#   inflating: test_images/image.4196.jpg
#   inflating: test_images/image.4197.jpg
#   inflating: test_images/image.4198.png
#   inflating: test_images/image.4199.jpg
#   inflating: test_images/image.42.jpg
#   inflating: test_images/image.420.png
#   inflating: test_images/image.4200.png
#   inflating: test_images/image.4201.jpg
#   inflating: test_images/image.4202.jpg
#   inflating: test_images/image.4203.png
#   inflating: test_images/image.4204.jpg
#   inflating: test_images/image.4205.jpg
#   inflating: test_images/image.4206.jpg
#   inflating: test_images/image.4207.jpg
#   inflating: test_images/image.4208.jpg
#   inflating: test_images/image.4209.jpg
#  extracting: test_images/image.421.jpg
#   inflating: test_images/image.4210.jpg
#   inflating: test_images/image.4211.jpg
#   inflating: test_images/image.4212.jpg
#   inflating: test_images/image.4213.jpg
#   inflating: test_images/image.4214.jpg
#   inflating: test_images/image.4215.png
#   inflating: test_images/image.4216.jpg
#   inflating: test_images/image.4217.jpg
#   inflating: test_images/image.4218.jpg
#   inflating: test_images/image.4219.jpg
#   inflating: test_images/image.422.jpg
#   inflating: test_images/image.4220.png
#   inflating: test_images/image.4221.jpg
#   inflating: test_images/image.4222.png
#   inflating: test_images/image.4223.png
#   inflating: test_images/image.4224.jpg
#   inflating: test_images/image.4225.jpg
#   inflating: test_images/image.4226.jpg
#   inflating: test_images/image.4227.jpg
#   inflating: test_images/image.4228.jpg
#   inflating: test_images/image.4229.jpg
#   inflating: test_images/image.423.jpg
#   inflating: test_images/image.4230.jpg
#   inflating: test_images/image.4231.jpg
#   inflating: test_images/image.4232.jpg
#   inflating: test_images/image.4233.jpg
#   inflating: test_images/image.4234.jpg
#  extracting: test_images/image.4235.jpg
#   inflating: test_images/image.4236.jpg
#   inflating: test_images/image.4237.jpg
#   inflating: test_images/image.4238.jpg
#   inflating: test_images/image.4239.jpg
#   inflating: test_images/image.424.jpg
#   inflating: test_images/image.4240.jpg
#   inflating: test_images/image.4241.jpg
#   inflating: test_images/image.4242.jpg
#   inflating: test_images/image.4243.jpg
#   inflating: test_images/image.4244.jpg
#   inflating: test_images/image.4245.jpg
#   inflating: test_images/image.4246.jpg
#   inflating: test_images/image.4247.jpg
#   inflating: test_images/image.4248.jpg
#   inflating: test_images/image.4249.png
#   inflating: test_images/image.425.jpg
#   inflating: test_images/image.4250.jpg
#   inflating: test_images/image.4251.jpg
#   inflating: test_images/image.4252.jpg
#   inflating: test_images/image.4253.jpg
#   inflating: test_images/image.4254.jpg
#   inflating: test_images/image.4255.jpg
#   inflating: test_images/image.4256.jpg
#   inflating: test_images/image.4257.jpg
#   inflating: test_images/image.4258.jpg
#   inflating: test_images/image.4259.jpg
#   inflating: test_images/image.426.jpg
#   inflating: test_images/image.4260.jpg
#   inflating: test_images/image.4261.jpg
#   inflating: test_images/image.4262.jpg
#   inflating: test_images/image.4263.jpg
#   inflating: test_images/image.4264.jpg
#   inflating: test_images/image.4265.jpg
#   inflating: test_images/image.4266.jpg
#   inflating: test_images/image.4267.jpg
#   inflating: test_images/image.4268.png
#   inflating: test_images/image.4269.jpg
#   inflating: test_images/image.427.jpg
#   inflating: test_images/image.4270.jpg
#   inflating: test_images/image.4271.jpg
#   inflating: test_images/image.4272.jpg
#   inflating: test_images/image.4273.jpg
#   inflating: test_images/image.4274.jpg
#   inflating: test_images/image.4275.jpg
#   inflating: test_images/image.4276.jpg
#   inflating: test_images/image.4277.jpg
#   inflating: test_images/image.4278.jpg
#   inflating: test_images/image.4279.jpg
#   inflating: test_images/image.428.jpg
#   inflating: test_images/image.4280.jpg
#   inflating: test_images/image.4281.jpg
#   inflating: test_images/image.4282.jpg
#   inflating: test_images/image.4283.jpg
#   inflating: test_images/image.4284.jpg
#  extracting: test_images/image.4285.jpg
#   inflating: test_images/image.4286.jpg
#   inflating: test_images/image.4287.jpg
#   inflating: test_images/image.4288.jpg
#   inflating: test_images/image.4289.jpg
#   inflating: test_images/image.429.jpg
#   inflating: test_images/image.4290.jpg
#   inflating: test_images/image.4291.jpg
#   inflating: test_images/image.4292.png
#   inflating: test_images/image.4293.jpg
#   inflating: test_images/image.4294.png
#   inflating: test_images/image.4295.png
#   inflating: test_images/image.4296.png
#   inflating: test_images/image.4297.png
#   inflating: test_images/image.4298.png
#   inflating: test_images/image.4299.png
#  extracting: test_images/image.43.PNG
#   inflating: test_images/image.430.jpg
#   inflating: test_images/image.4300.png
#   inflating: test_images/image.4301.jpg
#   inflating: test_images/image.4302.jpg
#   inflating: test_images/image.4303.jpg
#   inflating: test_images/image.4304.jpg
#   inflating: test_images/image.4305.jpg
#   inflating: test_images/image.4306.jpg
#   inflating: test_images/image.4307.jpg
#   inflating: test_images/image.4308.jpg
#   inflating: test_images/image.4309.jpg
#   inflating: test_images/image.7949.jpg
#   inflating: test_images/image.795.jpg
#   inflating: test_images/image.7950.jpg
#   inflating: test_images/image.7951.jpg
#   inflating: test_images/image.7952.jpg
#   inflating: test_images/image.7953.jpg
#   inflating: test_images/image.7954.jpg
#   inflating: test_images/image.7955.jpg
#   inflating: test_images/image.7956.jpg
#   inflating: test_images/image.7957.jpg
#   inflating: test_images/image.7958.jpg
#   inflating: test_images/image.7959.jpg
#   inflating: test_images/image.796.jpg
#   inflating: test_images/image.7960.jpg
#   inflating: test_images/image.7961.jpg
#   inflating: test_images/image.7962.jpg
#   inflating: test_images/image.7963.jpg
#   inflating: test_images/image.7964.jpg
#   inflating: test_images/image.7965.jpg
#   inflating: test_images/image.7966.jpg
#   inflating: test_images/image.7967.jpg
#   inflating: test_images/image.7968.jpg
#   inflating: test_images/image.7969.jpg
#   inflating: test_images/image.797.png
#   inflating: test_images/image.7970.jpg
#   inflating: test_images/image.7971.jpg
#   inflating: test_images/image.7972.jpg
#   inflating: test_images/image.7973.jpg
#   inflating: test_images/image.7974.jpg
#   inflating: test_images/image.7975.jpg
#   inflating: test_images/image.7976.jpg
#  extracting: test_images/image.7977.jpg
#   inflating: test_images/image.7978.jpg
#   inflating: test_images/image.7979.jpg
#   inflating: test_images/image.798.jpg
#  extracting: test_images/image.7980.png
#   inflating: test_images/image.7981.jpg
#   inflating: test_images/image.7982.jpg
#   inflating: test_images/image.7983.jpg
#   inflating: test_images/image.7984.jpg
#   inflating: test_images/image.7985.jpg
#   inflating: test_images/image.7986.jpg
#   inflating: test_images/image.7987.jpg
#   inflating: test_images/image.7988.jpg
#   inflating: test_images/image.7989.jpg
#   inflating: test_images/image.799.jpg
#   inflating: test_images/image.7990.jpg
#   inflating: test_images/image.7991.jpg
#   inflating: test_images/image.7992.jpeg
#   inflating: test_images/image.7993.jpg
#   inflating: test_images/image.7994.jpg
#   inflating: test_images/image.7995.jpg
#   inflating: test_images/image.7996.jpg
#   inflating: test_images/image.7997.jpg
#   inflating: test_images/image.7998.jpg
#   inflating: test_images/image.7999.jpg
#   inflating: test_images/image.8.jpg
#   inflating: test_images/image.80.jpg
#   inflating: test_images/image.800.jpg
#   inflating: test_images/image.8000.jpg
#   inflating: test_images/image.8001.jpg
#   inflating: test_images/image.8002.jpg
#   inflating: test_images/image.8003.jpg
#   inflating: test_images/image.8004.jpg
#   inflating: test_images/image.8005.jpg
#   inflating: test_images/image.8006.jpg
#   inflating: test_images/image.8007.jpg
#   inflating: test_images/image.8008.jpg
#   inflating: test_images/image.8009.jpg
#   inflating: test_images/image.801.jpg
#   inflating: test_images/image.8010.jpg
#   inflating: test_images/image.8011.jpg
#   inflating: test_images/image.8012.jpg
#   inflating: test_images/image.8013.jpg
#   inflating: test_images/image.8014.jpg
#   inflating: test_images/image.8015.jpg
#   inflating: test_images/image.8016.jpg
#   inflating: test_images/image.8017.jpg
#   inflating: test_images/image.8018.jpg
#   inflating: test_images/image.8019.jpg
#   inflating: test_images/image.802.jpg
#   inflating: test_images/image.8020.jpg
#   inflating: test_images/image.8021.jpg
#   inflating: test_images/image.8022.jpg
#   inflating: test_images/image.8023.jpg
#   inflating: test_images/image.8024.jpg
#   inflating: test_images/image.8025.jpg
#   inflating: test_images/image.8026.jpg
#   inflating: test_images/image.8027.jpg
#   inflating: test_images/image.8028.jpg
#   inflating: test_images/image.8029.jpg
#   inflating: test_images/image.803.jpg
#   inflating: test_images/image.8030.jpg
#   inflating: test_images/image.8031.jpg
#   inflating: test_images/image.8032.jpg
#   inflating: test_images/image.8033.jpg
#   inflating: test_images/image.8034.jpg
#   inflating: test_images/image.8035.jpg
#  extracting: test_images/image.8036.jpg
#   inflating: test_images/image.8037.jpg
#   inflating: test_images/image.8038.jpg
#   inflating: test_images/image.8039.jpg
#   inflating: test_images/image.804.jpg
#   inflating: test_images/image.8040.jpg
#   inflating: test_images/image.8041.jpg
#   inflating: test_images/image.8042.jpg
#   inflating: test_images/image.8043.jpg
#   inflating: test_images/image.8044.jpg
#   inflating: test_images/image.8045.jpg
#   inflating: test_images/image.8046.jpg
#   inflating: test_images/image.8047.png
#   inflating: test_images/image.8048.jpg
#   inflating: test_images/image.8049.jpg
#   inflating: test_images/image.805.jpg
#   inflating: test_images/image.8050.png
#   inflating: test_images/image.8051.jpg
#   inflating: test_images/image.8052.jpg
#   inflating: test_images/image.8053.jpg
#   inflating: test_images/image.8054.jpg
#   inflating: test_images/image.8055.jpg
#   inflating: test_images/image.8056.jpg
#   inflating: test_images/image.8057.jpg
#   inflating: test_images/image.8058.jpg
#   inflating: test_images/image.8059.jpg
#   inflating: test_images/image.806.jpg
#   inflating: test_images/image.8060.jpg
#   inflating: test_images/image.8061.jpg
#   inflating: test_images/image.8062.jpg
#   inflating: test_images/image.8063.jpg
#   inflating: test_images/image.8064.jpg
#   inflating: test_images/image.8065.jpg
#   inflating: test_images/image.8066.jpg
#   inflating: test_images/image.8067.jpg
#   inflating: test_images/image.8068.jpg
#   inflating: test_images/image.8069.jpg
#   inflating: test_images/image.807.jpg
#   inflating: test_images/image.8070.jpg
#   inflating: test_images/image.8071.jpg
#   inflating: test_images/image.8072.jpg
#   inflating: test_images/image.8073.jpg
#   inflating: test_images/image.8074.jpg
#   inflating: test_images/image.8075.jpg
#   inflating: test_images/image.8076.jpg
#   inflating: test_images/image.8077.jpg
#   inflating: test_images/image.8078.jpg
#   inflating: test_images/image.8079.jpg
#  extracting: test_images/image.808.jpg
#   inflating: test_images/image.8080.jpg
#   inflating: test_images/image.8081.jpg
#   inflating: test_images/image.8082.jpg
#   inflating: test_images/image.8083.jpg
#   inflating: test_images/image.8084.jpg
#   inflating: test_images/image.8085.jpg
#   inflating: test_images/image.8086.jpg
#   inflating: test_images/image.8087.jpg
#   inflating: test_images/image.8088.jpg
#   inflating: test_images/image.8089.jpg
#   inflating: test_images/image.809.jpg
#   inflating: test_images/image.8090.jpg
#   inflating: test_images/image.8091.jpg
#   inflating: test_images/image.8092.jpg
#   inflating: test_images/image.8093.jpg
#   inflating: test_images/image.8094.jpg
#   inflating: test_images/image.8095.jpg
#   inflating: test_images/image.8096.jpg
#   inflating: test_images/image.8097.jpg
#   inflating: test_images/image.8098.jpg
#   inflating: test_images/image.8099.jpg
#  extracting: test_images/image.81.png
#   inflating: test_images/image.810.jpg
#   inflating: test_images/image.811.jpg
#   inflating: test_images/image.812.jpg
#   inflating: test_images/image.813.jpg
#   inflating: test_images/image.814.jpg
#   inflating: test_images/image.815.jpg
#   inflating: test_images/image.816.jpg
#   inflating: test_images/image.817.jpg
#   inflating: test_images/image.818.jpg
#  extracting: test_images/image.819.png
#   inflating: test_images/image.82.jpg
#   inflating: test_images/image.820.jpg
#   inflating: test_images/image.821.jpg
#   inflating: test_images/image.822.jpg
#   inflating: test_images/image.823.jpg
#   inflating: test_images/image.824.jpg
#   inflating: test_images/image.825.jpg
#   inflating: test_images/image.826.jpg
#   inflating: test_images/image.827.jpg
#   inflating: test_images/image.828.jpg
#   inflating: test_images/image.829.jpg
#   inflating: test_images/image.83.jpg
#   inflating: test_images/image.830.jpg
#   inflating: test_images/image.831.jpg
#   inflating: test_images/image.832.jpg
#   inflating: test_images/image.833.jpg
#   inflating: test_images/image.834.jpg
#   inflating: test_images/image.835.jpg
#   inflating: test_images/image.836.jpg
#   inflating: test_images/image.837.jpg
#   inflating: test_images/image.838.jpg
#   inflating: test_images/image.839.jpg
#   inflating: test_images/image.84.jpg
#   inflating: test_images/image.840.jpg
#   inflating: test_images/image.841.jpg
#   inflating: test_images/image.842.jpg
#   inflating: test_images/image.843.jpg
#   inflating: test_images/image.844.jpg
#  extracting: test_images/image.845.png
#   inflating: test_images/image.846.jpg
#  extracting: test_images/image.847.jpg
#   inflating: test_images/image.848.jpg
#   inflating: test_images/image.849.jpg
#   inflating: test_images/image.85.jpg
#   inflating: test_images/image.850.jpg
#   inflating: test_images/image.851.jpg
#   inflating: test_images/image.852.jpg
#   inflating: test_images/image.853.jpg
#   inflating: test_images/image.854.jpg
#   inflating: test_images/image.855.jpg
#   inflating: test_images/image.856.jpg
#   inflating: test_images/image.857.jpg
#   inflating: test_images/image.858.jpg
#   inflating: test_images/image.859.jpg
#   inflating: test_images/image.86.jpg
#   inflating: test_images/image.860.jpg
#  extracting: test_images/image.861.jpg
#   inflating: test_images/image.862.jpg
#   inflating: test_images/image.863.jpg
#   inflating: test_images/image.864.jpg
#   inflating: test_images/image.865.jpg
#   inflating: test_images/image.866.jpg
#   inflating: test_images/image.867.jpg
#   inflating: test_images/image.868.jpg
#   inflating: test_images/image.869.jpg
#   inflating: test_images/image.87.jpg
#   inflating: test_images/image.870.jpg
#   inflating: test_images/image.871.jpg
#   inflating: test_images/image.872.jpg
#   inflating: test_images/image.873.jpg
#   inflating: test_images/image.874.jpg
#   inflating: test_images/image.875.jpg
#   inflating: test_images/image.876.jpg
#   inflating: test_images/image.877.jpg
#   inflating: test_images/image.878.jpg
#   inflating: test_images/image.879.jpg
#   inflating: test_images/image.88.jpg
#   inflating: test_images/image.880.jpg
#   inflating: test_images/image.881.jpg
#   inflating: test_images/image.882.jpg
#   inflating: test_images/image.883.jpg
#   inflating: test_images/image.884.jpg
#   inflating: test_images/image.885.jpg
#   inflating: test_images/image.886.jpg
#   inflating: test_images/image.887.jpg
#   inflating: test_images/image.888.jpg
#   inflating: test_images/image.889.jpg
#   inflating: test_images/image.89.jpg
#   inflating: test_images/image.890.jpg
#   inflating: test_images/image.891.jpg
#   inflating: test_images/image.892.jpg
#   inflating: test_images/image.893.jpg
#   inflating: test_images/image.894.jpg
#   inflating: test_images/image.895.jpg
#   inflating: test_images/image.896.jpg
#   inflating: test_images/image.897.jpg
#   inflating: test_images/image.898.jpg
#   inflating: test_images/image.899.jpg
#   inflating: test_images/image.9.jpg
#   inflating: test_images/image.90.jpg
#   inflating: test_images/image.900.jpg
#  extracting: test_images/image.901.jpg
#   inflating: test_images/image.902.jpg
#   inflating: test_images/image.903.jpg
#  extracting: test_images/image.904.jpg
#   inflating: test_images/image.905.jpg
#   inflating: test_images/image.906.jpg
#   inflating: test_images/image.907.jpg
#   inflating: test_images/image.908.jpg
#   inflating: test_images/image.909.jpg
#   inflating: test_images/image.91.jpg
#   inflating: test_images/image.910.jpg
#   inflating: test_images/image.911.jpg
#   inflating: test_images/image.912.jpg
#   inflating: test_images/image.913.jpg
#   inflating: test_images/image.914.jpg
#   inflating: test_images/image.915.jpg
#  extracting: test_images/image.916.jpg
#   inflating: test_images/image.917.jpg
#   inflating: test_images/image.918.jpg
#   inflating: test_images/image.919.jpg
#   inflating: test_images/image.92.jpg
#   inflating: test_images/image.920.jpg
#   inflating: test_images/image.921.jpg
#   inflating: test_images/image.922.jpg
#   inflating: test_images/image.923.jpg
#   inflating: test_images/image.924.jpg
#   inflating: test_images/image.925.jpg
#   inflating: test_images/image.926.jpg
#   inflating: test_images/image.927.jpg
#  extracting: test_images/image.928.jpg
#   inflating: test_images/image.929.jpg
#   inflating: test_images/image.93.jpg
#   inflating: test_images/image.930.jpg
#   inflating: test_images/image.931.jpg
#   inflating: test_images/image.932.jpg
#   inflating: test_images/image.933.jpg
#  extracting: test_images/image.934.jpg
#   inflating: test_images/image.935.jpg
#   inflating: test_images/image.936.jpg
#   inflating: test_images/image.937.jpg
#   inflating: test_images/image.938.jpg
#   inflating: test_images/image.939.jpg
#   inflating: test_images/image.94.jpg
#   inflating: test_images/image.940.jpg
#   inflating: test_images/image.941.jpg
#   inflating: test_images/image.942.jpg
#   inflating: test_images/image.943.jpg
#   inflating: test_images/image.944.jpg
#   inflating: test_images/image.945.jpg
#   inflating: test_images/image.946.jpg
#   inflating: test_images/image.947.jpg
#   inflating: test_images/image.948.jpg
#   inflating: test_images/image.949.jpg
#   inflating: test_images/image.95.jpg
#   inflating: test_images/image.950.jpg
#   inflating: test_images/image.951.jpg
#   inflating: test_images/image.952.jpg
#   inflating: test_images/image.953.jpg
#   inflating: test_images/image.954.jpg
#   inflating: test_images/image.955.jpg
#   inflating: test_images/image.956.jpg
#   inflating: test_images/image.957.jpg
#   inflating: test_images/image.958.jpg
#   inflating: test_images/image.959.jpg
#   inflating: test_images/image.96.jpg
#  extracting: test_images/image.960.jpg
#   inflating: test_images/image.961.jpg
#   inflating: test_images/image.962.jpg
#   inflating: test_images/image.963.jpg
#   inflating: test_images/image.964.jpg
#   inflating: test_images/image.965.jpg
#   inflating: test_images/image.966.jpg
#   inflating: test_images/image.967.jpg
#   inflating: test_images/image.968.jpg
#   inflating: test_images/image.969.jpg
#   inflating: test_images/image.97.jpg
#   inflating: test_images/image.970.jpg
#   inflating: test_images/image.971.jpg
#   inflating: test_images/image.972.jpg
#   inflating: test_images/image.973.jpg
#   inflating: test_images/image.974.jpg
#   inflating: test_images/image.975.jpg
#   inflating: test_images/image.976.jpg
#   inflating: test_images/image.977.jpg
#   inflating: test_images/image.978.jpg
#   inflating: test_images/image.979.jpg
#   inflating: test_images/image.98.jpg
#   inflating: test_images/image.980.jpg
#   inflating: test_images/image.981.jpg
#   inflating: test_images/image.982.jpg
#   inflating: test_images/image.983.jpg
#   inflating: test_images/image.984.jpg
#   inflating: test_images/image.985.jpg
#   inflating: test_images/image.986.jpg
#   inflating: test_images/image.987.jpg
#   inflating: test_images/image.988.jpg
#   inflating: test_images/image.989.jpg
#   inflating: test_images/image.99.jpg
#   inflating: test_images/image.990.jpg
#   inflating: test_images/image.991.jpg
#   inflating: test_images/image.992.jpg
#   inflating: test_images/image.993.jpg
#   inflating: test_images/image.994.jpg
#   inflating: test_images/image.995.jpg
#   inflating: test_images/image.996.jpg
#   inflating: test_images/image.997.jpg
#   inflating: test_images/image.998.jpg
#   inflating: test_images/image.999.jpg
# Archive:  test_data.zip
#   inflating: test_data/en.test.data.v1.1.txt
#   inflating: test_data/en.test.gold.v1.1.txt
#   inflating: test_data/fa.test.data.txt
#   inflating: test_data/fa.test.gold.txt
#   inflating: test_data/it.test.data.v1.1.txt
#   inflating: test_data/it.test.gold.v1.1.txt
#   inflating: test_data/README.txt

# %% [markdown]
# ## Load datasets to pandas dataframe

# %%
def load_dataset_data_frame(parts):
    data_frames = []
    for part in parts:
        print(f"Loading {part} data...")
        df1 = pd.read_csv(
            f'semeval-2023-task-1-V-WSD-v1/{part if "test" not in part else "test"}_v1/{part}.data.v1.txt', 
            sep='\t', 
            header=None
        )
        df2 = pd.read_csv(
            f'semeval-2023-task-1-V-WSD-v1/{part if "test" not in part else "test"}_v1/{part}.gold.v1.txt', 
            sep='\t', 
            header=None
        )

        df1.rename(
            columns={
                0: 'word', 
                1: 'phrase', 
                2: 'image_0_name', 
                3: 'image_1_name', 
                4: 'image_2_name', 
                5: 'image_3_name', 
                6: 'image_4_name', 
                7: 'image_5_name', 
                8: 'image_6_name', 
                9: 'image_7_name', 
                10: 'image_8_name', 
                11: 'image_9_name'
            },
            inplace=True
        )
        df2.rename(
            columns={
                0: 'gold_name'
            },
            inplace=True
        )
        
        # TODO: Add columns "image_{i}" to "df1" which are images' path. (~6 lines)
        def add_image_path(row, i):
            return f"/content/semeval-2023-task-1-V-WSD-v1/{part if 'test' not in part else 'test'}_v1/{part if 'test' not in part else 'test'}_images_v1/{row[f'image_{i}_name']}"
        
        for ind in range(10):
            df1[f"image_{ind}"] = df1.apply(add_image_path, i=ind, axis=1)
        

        # end of TODO

        df = pd.merge(df1, df2, left_index=True, right_index=True)
        df[f'labels'] = df.apply(lambda x: [i for i in range(10) if x[f'image_{i}_name'] == x['gold_name']][0], axis=1)
        data_frames.append(df)
        print(f"Done; {part} data loaded ({len(df)} rows)!")
    return data_frames

train_df, trial_df, en_test_df, it_test_df, fa_test_df = load_dataset_data_frame(['train', 'trial', 'en.test', 'it.test', 'fa.test'])
# Out:
# Loading train data...
# Done; train data loaded (12869 rows)!
# Loading trial data...
# Done; trial data loaded (16 rows)!
# Loading en.test data...
# Done; en.test data loaded (463 rows)!
# Loading it.test data...
# Done; it.test data loaded (305 rows)!
# Loading fa.test data...
# Done; fa.test data loaded (200 rows)!

# %%
trial_df
# Out:
#               word                         phrase   image_0_name  \
# 0        andromeda                 andromeda tree  image.155.jpg
# 1           angora                    angora city    image.5.jpg
# 2         anteater             marsupial anteater  image.147.jpg
# 3             bank                   bank erosion  image.104.jpg
# 4           router                internet router  image.127.jpg
# 5            stick                   centre stick  image.100.jpg
# 6            swing                      swing hit   image.51.jpg
# 7             tube                    london tube  image.105.jpg
# 8            venus                  venus surface   image.60.jpg
# 9            wheel                 breaking wheel  image.111.jpg
# 10           white                     white yolk  image.130.jpg
# 11      acrobatics           acrobatics maneuvers  image.120.jpg
# 12          adalia                 biology adalia   image.44.jpg
# 13  administration  administration prime minister   image.39.jpg
# 14           amber                   amber bijoux   image.10.jpg
# 15        ambrosia                  ambrosia food   image.31.jpg
#
#      image_1_name   image_2_name   image_3_name   image_4_name   image_5_name  \
# 0    image.68.jpg    image.9.jpg   image.72.jpg  image.158.jpg   image.86.jpg
# 1    image.52.jpg   image.96.jpg   image.70.jpg   image.46.jpg   image.91.jpg
# 2    image.16.jpg  image.107.jpg  image.135.jpg   image.93.jpg   image.59.jpg
# 3    image.64.jpg  image.108.jpg   image.80.jpg   image.21.jpg   image.99.jpg
# 4     image.0.jpg   image.20.jpg   image.18.jpg  image.112.jpg   image.97.jpg
# 5    image.62.jpg  image.156.jpg   image.78.jpg  image.122.jpg   image.81.jpg
# 6   image.141.jpg   image.11.jpg   image.77.jpg   image.95.jpg   image.33.jpg
# 7   image.129.jpg   image.41.jpg   image.43.jpg  image.102.jpg   image.28.jpg
# 8    image.37.jpg   image.83.jpg   image.94.jpg   image.17.jpg   image.29.jpg
# 9    image.69.jpg   image.82.jpg   image.73.jpg   image.74.jpg   image.48.jpg
# 10  image.154.jpg   image.71.jpg   image.45.jpg  image.136.jpg   image.42.jpg
# 11  image.133.jpg   image.58.jpg  image.126.jpg   image.57.jpg  image.134.jpg
# 12    image.2.jpg   image.22.jpg  image.152.jpg   image.66.jpg  image.116.jpg
# 13  image.109.jpg  image.119.jpg  image.153.jpg   image.90.jpg   image.49.jpg
# 14   image.85.jpg  image.128.jpg  image.159.jpg  image.142.jpg  image.144.jpg
# 15   image.84.jpg  image.103.jpg  image.125.jpg  image.151.jpg   image.61.jpg
#
#      image_6_name   image_7_name  ...  \
# 0     image.7.jpg  image.132.jpg  ...
# 1    image.76.jpg  image.139.jpg  ...
# 2    image.88.png  image.131.jpg  ...
# 3   image.117.jpg  image.146.jpg  ...
# 4    image.24.jpg    image.1.jpg  ...
# 5   image.148.jpg  image.114.jpg  ...
# 6    image.65.jpg  image.113.jpg  ...
# 7    image.79.jpg  image.138.jpg  ...
# 8    image.32.jpg  image.137.jpg  ...
# 9   image.140.jpg  image.118.jpg  ...
# 10    image.4.jpg   image.38.jpg  ...
# 11   image.67.jpg   image.30.jpg  ...
# 12   image.25.jpg   image.47.jpg  ...
# 13   image.75.jpg   image.15.jpg  ...
# 14   image.35.jpg   image.23.jpg  ...
# 15  image.101.jpg   image.98.jpg  ...
#
#                                               image_2  \
# 0   /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 1   /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 2   /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 3   /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 4   /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 5   /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 6   /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 7   /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 8   /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 9   /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 10  /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 11  /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 12  /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 13  /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 14  /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 15  /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
#
#                                               image_3  \
# 0   /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 1   /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 2   /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 3   /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 4   /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 5   /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 6   /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 7   /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 8   /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 9   /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 10  /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 11  /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 12  /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 13  /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 14  /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 15  /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
#
#                                               image_4  \
# 0   /content/semeval-2023-task-1-V-WSD-v1/trial_v1...
# 8   /content/semeval-2023-task-1-V-WSD-v1/trial_v1...  image.124.jpg      9
# 9   /content/semeval-2023-task-1-V-WSD-v1/trial_v1...  image.118.jpg      7
# 10  /content/semeval-2023-task-1-V-WSD-v1/trial_v1...   image.71.jpg      2
# 11  /content/semeval-2023-task-1-V-WSD-v1/trial_v1...  image.134.jpg      5
# 12  /content/semeval-2023-task-1-V-WSD-v1/trial_v1...   image.25.jpg      6
# 13  /content/semeval-2023-task-1-V-WSD-v1/trial_v1...  image.149.jpg      9
# 14  /content/semeval-2023-task-1-V-WSD-v1/trial_v1...   image.85.jpg      1
# 15  /content/semeval-2023-task-1-V-WSD-v1/trial_v1...  image.103.jpg      2
#
# [16 rows x 24 columns]

# %% [markdown]
# ## Create HuggingFace dataset from pandas dataframe

# %%
# TODO: Specify each column datatype, refer to the output of the last cell (use "Features" class) (~1 line)
features = Features({
  'word': Value(dtype='string', id=None),
  'phrase': Value(dtype='string', id=None),
  'image_0_name': Value(dtype='string', id=None),
  'image_1_name': Value(dtype='string', id=None),
  'image_2_name': Value(dtype='string', id=None),
  'image_3_name': Value(dtype='string', id=None),
  'image_4_name': Value(dtype='string', id=None),
  'image_5_name': Value(dtype='string', id=None),
  'image_6_name': Value(dtype='string', id=None),
  'image_7_name': Value(dtype='string', id=None),
  'image_8_name': Value(dtype='string', id=None),
  'image_9_name': Value(dtype='string', id=None),
  'image_0': Value(dtype='string', id=None),
  'image_1': Value(dtype='string', id=None),
  'image_2': Value(dtype='string', id=None),
  'image_3': Value(dtype='string', id=None),
  'image_4': Value(dtype='string', id=None),
  'image_5': Value(dtype='string', id=None),
  'image_6': Value(dtype='string', id=None),
  'image_7': Value(dtype='string', id=None),
  'image_8': Value(dtype='string', id=None),
  'image_9': Value(dtype='string', id=None),
  'gold_name': Value(dtype='string', id=None),
  'labels': ClassLabel(num_classes=10, names=[str(i)for i in range(10)], names_file=None, id=None),
})

# end of TODO

train_dataset = Dataset.from_pandas(train_df, features=features).shuffle(seed=GLOBAL_SEED).select(range(496))
trial_dataset = Dataset.from_pandas(trial_df, features=features).shuffle(seed=GLOBAL_SEED) # Whole trial dataset
en_test_dataset = Dataset.from_pandas(en_test_df, features=features).shuffle(seed=GLOBAL_SEED).select(range(64))
it_test_dataset = Dataset.from_pandas(it_test_df, features=features).shuffle(seed=GLOBAL_SEED).select(range(64))
fa_test_dataset = Dataset.from_pandas(fa_test_df, features=features).shuffle(seed=GLOBAL_SEED).select(range(64))

# %%
trial_dataset
# Out:
# Dataset({
#     features: ['word', 'phrase', 'image_0_name', 'image_1_name', 'image_2_name', 'image_3_name', 'image_4_name', 'image_5_name', 'image_6_name', 'image_7_name', 'image_8_name', 'image_9_name', 'image_0', 'image_1', 'image_2', 'image_3', 'image_4', 'image_5', 'image_6', 'image_7', 'image_8', 'image_9', 'gold_name', 'labels'],
#     num_rows: 16
# })

# %% [markdown]
# ## Preprocess data using AltCLIP processor

# %%
def get_woaw(phrase, word) -> str:
    # TODO: Omit the word from phrase (~1 line)
    woaw = phrase.replace(word, '').strip()
    # end of TODO
    return woaw

# %%
processor = AltCLIPProcessor.from_pretrained("BAAI/AltCLIP")

def process_function(examples):
    # TODO: Call processor and pass the pharse, WOAW (use "omit_ambiguous_word") and images as its arguments
    # Use return_tensors="pt", padding="max_length", truncation=True, max_length=64 (~1 line)
    processor_output = processor(text=[examples['phrase'], get_woaw(examples['phrase'], examples['word'])], images=[PIL_Image.open(examples[f"image_{i}"]) for i in range(10)], return_tensors="pt", padding="max_length", truncation=True, max_length=64)
    # end of TODO

    processor_output['phrase_input_ids'] = processor_output['input_ids'][:1,:]
    processor_output['phrase_attention_mask'] = processor_output['attention_mask'][:1,:]
    processor_output['woaw_input_ids'] = processor_output['input_ids'][1:,:]
    processor_output['woaw_attention_mask'] = processor_output['attention_mask'][1:,:]
    processor_output.pop('input_ids')
    processor_output.pop('attention_mask')
    return processor_output

processed_train_dataset = train_dataset.map(process_function, writer_batch_size=32, cache_file_name='alt_train_dataset_cache')
processed_trial_dataset = trial_dataset.map(process_function, writer_batch_size=32, cache_file_name='alt_trial_dataset_cache')
processed_en_test_dataset = en_test_dataset.map(process_function, writer_batch_size=32, cache_file_name='alt_en_test_dataset_cache')
processed_it_test_dataset = it_test_dataset.map(process_function, writer_batch_size=32, cache_file_name='alt_it_test_dataset_cache')
processed_fa_test_dataset = fa_test_dataset.map(process_function, writer_batch_size=32, cache_file_name='alt_fa_test_dataset_cache')
# Out:
# Downloading (…)rocessor_config.json:   0%|          | 0.00/559 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/513 [00:00<?, ?B/s]
# Downloading (…)tencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# Map:   0%|          | 0/496 [00:00<?, ? examples/s]
# Map:   0%|          | 0/16 [00:00<?, ? examples/s]
# Map:   0%|          | 0/64 [00:00<?, ? examples/s]
# Map:   0%|          | 0/64 [00:00<?, ? examples/s]
# Map:   0%|          | 0/64 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:975: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(

# %%
processed_trial_dataset

# %% [markdown]
# ## Extract and save features using AltCLIP

# %%
datasets_dict = {
    'train': concatenate_datasets([processed_train_dataset, processed_trial_dataset]).shuffle(seed=GLOBAL_SEED),
    'en_test': processed_en_test_dataset,
    'it_test': processed_it_test_dataset,
    'fa_test': processed_fa_test_dataset
}

# %%
def get_batch(dataset, batch_size, i):
    # TODO: Return the i-th batch from dataset (~1 line)
    batch = dataset.select([i])
    #end of TODO
    return batch

def remove_second_dim(tensor):
    # TODO: remove the second dim of tensor (~1 line)
    # print(tensor.size())
    tensor = tensor.squeeze(1)
    # print("after")
    # print(tensor.size())
    # end of TODO
    return tensor

# %%
def extract_features(datasets_dict, batch_size=1):
    model = AltCLIPModel.from_pretrained("BAAI/AltCLIP").to('cuda:0')
    for processed_dataset_name, processed_dataset in datasets_dict.items():
        features_directory = f'alt_{processed_dataset_name}_features'
        if os.path.exists(features_directory):
            shutil.rmtree(features_directory, ignore_errors=True)
        os.mkdir(features_directory)
        processed_dataset.set_format(type='torch', columns=['phrase_input_ids', 'phrase_attention_mask', 'woaw_input_ids', 'woaw_attention_mask', 'pixel_values', 'labels'])
        for i in tqdm(range(0, processed_dataset.num_rows, batch_size)):
            batch = get_batch(processed_dataset, batch_size, i)[:]
            phrase_input_ids = remove_second_dim(batch['phrase_input_ids'])
            phrase_attention_mask = remove_second_dim(batch['phrase_attention_mask'])
            woaw_input_ids = remove_second_dim(batch['woaw_input_ids'])
            woaw_attention_mask = remove_second_dim(batch['woaw_attention_mask'])
            batch_size, image_count, image_dim0, image_dim1, image_dim2 = batch['pixel_values'].shape
            # TODO: Reshape batch['pixel_values'] to (batch_size * image_count, image_dim0, image_dim1, image_dim2) (~1 line)
            pixel_values = batch['pixel_values'].reshape(batch_size * image_count, image_dim0, image_dim1, image_dim2)
            # end of TODO

            # TODO: Move phrase_input_ids, phrase_attention_mask, woaw_input_ids, woaw_attention_mask, pixel_values to GPU (~5 lines)
            phrase_input_ids = phrase_input_ids.to("cuda:0")
            phrase_attention_mask = phrase_attention_mask.to("cuda:0")
            woaw_input_ids = woaw_input_ids.to("cuda:0")
            woaw_attention_mask = woaw_attention_mask.to("cuda:0")
            pixel_values = pixel_values.to("cuda:0")
            # end of TODO
            
            torch.save(torch.unsqueeze(model.get_text_features(phrase_input_ids, phrase_attention_mask), dim=1), f'{features_directory}/phrase_features_{i}.pt')
            torch.save(torch.unsqueeze(model.get_text_features(woaw_input_ids, woaw_attention_mask), dim=1), f'{features_directory}/woaw_features_{i}.pt')
            torch.save(torch.reshape(model.get_image_features(pixel_values), (batch_size, image_count, -1)), f'{features_directory}/image_features_{i}.pt')
    
extract_features(datasets_dict)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/5.13k [00:00<?, ?B/s]
# `text_config_dict` is provided which will be used to initialize `AltCLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# Downloading pytorch_model.bin:   0%|          | 0.00/3.46G [00:00<?, ?B/s]
# 100%|██████████| 512/512 [06:52<00:00,  1.24it/s]
# 100%|██████████| 64/64 [00:52<00:00,  1.23it/s]
# 100%|██████████| 64/64 [00:51<00:00,  1.23it/s]
# 100%|██████████| 64/64 [00:52<00:00,  1.21it/s]

# %% [markdown]
# ## Add exctracted features to HuggingFace datasets

# %% [markdown]
# **Restart Your Runtime Here to Avoid Out of Memory Issue!**

# %%
os.kill(os.getpid(), 9)

# %% [markdown]
# ### Import requirements after restart again

# %%
from tqdm import tqdm
import gc
import os
import shutil
import glob
import random
import numpy as np
import torch
from torch import nn
import pandas as pd
from PIL import Image as PIL_Image
from PIL import ImageFile

from dataclasses import dataclass
from typing import Optional, Tuple, Union

import evaluate


from datasets import Dataset, Features, Value, Image, ClassLabel, concatenate_datasets
from transformers import AltCLIPProcessor, AltCLIPModel
from transformers.configuration_utils import PretrainedConfig
from transformers.models.altclip.modeling_altclip import AltCLIPEncoderLayer
from transformers.modeling_utils import PreTrainedModel
from transformers.modeling_outputs import BaseModelOutput, ModelOutput
from transformers import TrainingArguments, Trainer

# %% [markdown]
# ### Set some parameters to have determinism after restart again

# %%
ImageFile.LOAD_TRUNCATED_IMAGES = True
PIL_Image.MAX_IMAGE_PIXELS = 933120000

GLOBAL_SEED = 10

np.random.seed(GLOBAL_SEED)
random.seed(GLOBAL_SEED)
torch.manual_seed(GLOBAL_SEED)
torch.use_deterministic_algorithms(True)
# %env CUBLAS_WORKSPACE_CONFIG=:4096:8
# Out:
# env: CUBLAS_WORKSPACE_CONFIG=:4096:8

# %% [markdown]
# ### Load datasets from cache files

# %%
processed_train_dataset = Dataset.from_file('alt_train_dataset_cache')
processed_trial_dataset = Dataset.from_file('alt_trial_dataset_cache')
processed_en_test_dataset = Dataset.from_file('alt_en_test_dataset_cache')
processed_it_test_dataset = Dataset.from_file('alt_it_test_dataset_cache')
processed_fa_test_dataset = Dataset.from_file('alt_fa_test_dataset_cache')

# %% [markdown]
# ### Add features to datasets

# %%
datasets_dict = {
    'train': concatenate_datasets([processed_train_dataset, processed_trial_dataset]).shuffle(seed=GLOBAL_SEED),
    'en_test': processed_en_test_dataset,
    'it_test': processed_it_test_dataset,
    'fa_test': processed_fa_test_dataset
}
# Out:
# WARNING:datasets.arrow_dataset:Loading cached shuffled indices for dataset at /content/cache-fa6cab74ca739d77.arrow

# %%
def add_features_to_datasets(datasets_dict, batch_size=1):
    for processed_dataset_name, processed_dataset in datasets_dict.items():
        datasets_dict[processed_dataset_name] = datasets_dict[processed_dataset_name].remove_columns([
            'phrase_input_ids', 'phrase_attention_mask', 'woaw_input_ids', 'woaw_attention_mask', 'pixel_values'
        ])
        features_directory = f'alt_{processed_dataset_name}_features'
        phrase_features = []
        woaw_features = []
        image_features = []
        for i in tqdm(range(0, processed_dataset.num_rows, batch_size)):
            phrase_features.append(torch.load(f'{features_directory}/phrase_features_{i}.pt'))
            woaw_features.append(torch.load(f'{features_directory}/woaw_features_{i}.pt'))
            image_features.append(torch.load(f'{features_directory}/image_features_{i}.pt'))
        phrase_features = torch.cat(phrase_features, dim=0)
        woaw_features = torch.cat(woaw_features, dim=0)
        image_features = torch.cat(image_features, dim=0)

        shutil.rmtree(features_directory, ignore_errors=True)

        # TODO: Add phrase_features, woaw_features, image_features to datasets_dict[processed_dataset_name] (~3 lines)
        datasets_dict[processed_dataset_name] = datasets_dict[processed_dataset_name].add_column('phrase_features', phrase_features.tolist())
        datasets_dict[processed_dataset_name] = datasets_dict[processed_dataset_name].add_column('woaw_features', woaw_features.tolist())
        datasets_dict[processed_dataset_name] = datasets_dict[processed_dataset_name].add_column('image_features', image_features.tolist())
        
        # end of TODO


add_features_to_datasets(datasets_dict)
# Out:
# 100%|██████████| 512/512 [00:14<00:00, 35.96it/s]
# Flattening the indices:   0%|          | 0/512 [00:00<?, ? examples/s]
# 100%|██████████| 64/64 [00:00<00:00, 231.82it/s]
# 100%|██████████| 64/64 [00:00<00:00, 538.34it/s]
# 100%|██████████| 64/64 [00:00<00:00, 299.35it/s]

# %%
datasets_dict['train']
# Out:
# Dataset({
#     features: ['word', 'phrase', 'image_0_name', 'image_1_name', 'image_2_name', 'image_3_name', 'image_4_name', 'image_5_name', 'image_6_name', 'image_7_name', 'image_8_name', 'image_9_name', 'image_0', 'image_1', 'image_2', 'image_3', 'image_4', 'image_5', 'image_6', 'image_7', 'image_8', 'image_9', 'gold_name', 'labels', 'phrase_features', 'woaw_features', 'image_features'],
#     num_rows: 512
# })

# %% [markdown]
# # Train and evaluate

# %% [markdown]
# ## Construct model

# %% [markdown]
# ### Model config class

# %%
class RAltCLIPConfig(PretrainedConfig):

    def __init__(
        self,
        hidden_size=768,
        intermediate_size=3072,
        num_hidden_layers=3,
        num_attention_heads=8,
        hidden_act="quick_gelu",
        layer_norm_eps=1e-05,
        attention_dropout=0.0,
        num_images_to_rank=10,
        logit_scale_init_value=2.6592,
        loss_func="CE",
        **kwargs
    ):
        super().__init__(**kwargs)

        self.hidden_size = hidden_size
        self.intermediate_size = intermediate_size
        self.num_hidden_layers = num_hidden_layers
        self.num_attention_heads = num_attention_heads
        self.attention_dropout = attention_dropout
        self.hidden_act = hidden_act
        self.layer_norm_eps = layer_norm_eps
        self.num_images_to_rank = num_images_to_rank
        self.logit_scale_init_value = logit_scale_init_value
        self.loss_func = loss_func

# %% [markdown]
# ### Encoder class

# %%
# Copied from transformers.models.clip.modeling_altclip.AltCLIPEncoder with AltCLIP->RAltCLIP
class RAltCLIPEncoder(nn.Module):
    """
    Transformer encoder consisting of `config.num_hidden_layers` self attention layers. Each layer is a
    [`AltCLIPEncoderLayer`].
    Args:
        config: AltCLIPConfig
    """

    def __init__(self, config: RAltCLIPConfig):
        super().__init__()
        self.config = config
        self.layers = nn.ModuleList([AltCLIPEncoderLayer(config) for _ in range(config.num_hidden_layers)])
        self.gradient_checkpointing = False

    def forward(
        self,
        inputs_embeds,
        attention_mask: Optional[torch.Tensor] = None,
        causal_attention_mask: Optional[torch.Tensor] = None,
        output_attentions: Optional[bool] = None,
        output_hidden_states: Optional[bool] = None,
        return_dict: Optional[bool] = None,
    ) -> Union[Tuple, BaseModelOutput]:
        r"""
        Args:
            inputs_embeds (`torch.FloatTensor` of shape `(batch_size, sequence_length, hidden_size)`):
                Optionally, instead of passing `input_ids` you can choose to directly pass an embedded representation.
                This is useful if you want more control over how to convert `input_ids` indices into associated vectors
                than the model's internal embedding lookup matrix.
            attention_mask (`torch.Tensor` of shape `(batch_size, sequence_length)`, *optional*):
                Mask to avoid performing attention on padding token indices. Mask values selected in `[0, 1]`:
                - 1 for tokens that are **not masked**,
                - 0 for tokens that are **masked**.
                [What are attention masks?](../glossary#attention-mask)
            causal_attention_mask (`torch.Tensor` of shape `(batch_size, sequence_length)`, *optional*):
                Causal mask for the text model. Mask values selected in `[0, 1]`:
                - 1 for tokens that are **not masked**,
                - 0 for tokens that are **masked**.
                [What are attention masks?](../glossary#attention-mask)
            output_attentions (`bool`, *optional*):
                Whether or not to return the attentions tensors of all attention layers. See `attentions` under
                returned tensors for more detail.
            output_hidden_states (`bool`, *optional*):
                Whether or not to return the hidden states of all layers. See `hidden_states` under returned tensors
                for more detail.
            return_dict (`bool`, *optional*):
                Whether or not to return a [`~utils.ModelOutput`] instead of a plain tuple.
        """
        output_attentions = output_attentions if output_attentions is not None else self.config.output_attentions
        output_hidden_states = (
            output_hidden_states if output_hidden_states is not None else self.config.output_hidden_states
        )
        return_dict = return_dict if return_dict is not None else self.config.use_return_dict

        encoder_states = () if output_hidden_states else None
        all_attentions = () if output_attentions else None

        hidden_states = inputs_embeds
        for idx, encoder_layer in enumerate(self.layers):
            if output_hidden_states:
                encoder_states = encoder_states + (hidden_states,)
            if self.gradient_checkpointing and self.training:

                def create_custom_forward(module):
                    def custom_forward(*inputs):
                        return module(*inputs, output_attentions)

                    return custom_forward

                layer_outputs = torch.utils.checkpoint.checkpoint(
                    create_custom_forward(encoder_layer),
                    hidden_states,
                    attention_mask,
                    causal_attention_mask,
                )
            else:
                layer_outputs = encoder_layer(
                    hidden_states,
                    attention_mask,
                    causal_attention_mask,
                    output_attentions=output_attentions,
                )

            hidden_states = layer_outputs[0]

            if output_attentions:
                all_attentions = all_attentions + (layer_outputs[1],)

        if output_hidden_states:
            encoder_states = encoder_states + (hidden_states,)

        if not return_dict:
            return tuple(v for v in [hidden_states, encoder_states, all_attentions] if v is not None)
        return BaseModelOutput(
            last_hidden_state=hidden_states, hidden_states=encoder_states, attentions=all_attentions
        )

# %% [markdown]
# ### Output data class

# %%
@dataclass
class RAltCLIPOutput(ModelOutput):
    loss: Optional[torch.FloatTensor] = None
    logits: torch.FloatTensor = None

# %% [markdown]
# ### Model class

# %%
class RAltCLIPModel(PreTrainedModel):
    """Relative AltCLIP"""

    config_class = RAltCLIPConfig
    
    def __init__(self, config: RAltCLIPConfig):
        super().__init__(config)
        self.rank_encoder = RAltCLIPEncoder(config)
        self.logit_scale = nn.Parameter(torch.ones([]) * config.logit_scale_init_value)
        self.num_images_to_rank = config.num_images_to_rank
        self.loss_func = config.loss_func

    def forward(
        self,
        image_features: torch.FloatTensor,
        phrase_features: torch.FloatTensor,
        woaw_features: Optional[torch.FloatTensor] = None,
        labels: Optional[torch.LongTensor] = None,
    ) -> RAltCLIPOutput:
        if woaw_features != None:
            phrase_image_embeds = torch.cat((phrase_features, image_features, woaw_features), dim=1)
        else:
            phrase_image_embeds = torch.cat((phrase_features, image_features), dim=1)

        # TODO: Pass phrase_image_embeds to rank_encoder and get sum of all hidden states (~2 lines)
        rank_encoder_output = self.rank_encoder(phrase_image_embeds)
        hidden_states_sum = torch.sum(torch.stack(rank_encoder_output.hidden_states), dim=0)
        # end of TODO
        
        # normalized features
        hidden_states_sum = hidden_states_sum / hidden_states_sum.norm(p=2, dim=-1, keepdim=True)
        
        phrase_embeds_sum = hidden_states_sum[:,0,:].unsqueeze(1)
        image_embeds_sum = hidden_states_sum[:,1:11,:]
        
        # cosine similarity as logits
        logit_scale = self.logit_scale.exp()
        logits_per_phrase = torch.matmul(phrase_embeds_sum, torch.transpose(image_embeds_sum, -1, -2)) * logit_scale
        logits = logits_per_phrase.squeeze(1)

        
        loss = None
        if labels is not None:
            if self.loss_func == 'CE':
                output_loss_fct = nn.CrossEntropyLoss()
                loss = output_loss_fct(logits.view(-1, self.num_images_to_rank), labels.view(-1))
            elif self.loss_func == 'SIM':
                _, _, hidden_size = phrase_embeds_sum.shape
                similarity_loss_fct = nn.CosineEmbeddingLoss()
                similarity_labels = torch.nn.functional.one_hot(labels, self.num_images_to_rank)
                similarity_labels = torch.where(similarity_labels == 1, 1, -1)
                loss = similarity_loss_fct(
                    torch.repeat_interleave(phrase_embeds_sum, self.num_images_to_rank, dim=1).reshape(-1, hidden_size), 
                    image_embeds_sum.reshape(-1, hidden_size), 
                    similarity_labels.reshape(-1)
                )
            
        return RAltCLIPOutput(
            loss=loss,
            logits=logits,
        )

# %% [markdown]
# ## Load evaluation metrics

# %%
accuracy_metric = evaluate.load('accuracy')
mrr_metric = evaluate.load('posicube/mean_reciprocal_rank')

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    accuracy = accuracy_metric.compute(predictions=predictions.argmax(axis=-1), references=labels)
    mrr = mrr_metric.compute(predictions=np.where(np.argsort(-predictions, axis=1) == np.expand_dims(labels, axis=1))[1])
    return {'accuracy': accuracy['accuracy'], 'mrr': mrr['mrr']}

# %% [markdown]
# ## Train and evaluate

# %%
model_name = 'RAltCLIP_CE_12_T'

def model_init():
    config = RAltCLIPConfig(dropout=0.5, attention_dropout=0.5, loss_func='CE', output_hidden_states=True)
    model = RAltCLIPModel(config)
    return model

training_args = TrainingArguments(
    output_dir=model_name,
    logging_strategy='epoch',
    logging_steps=1,
    save_strategy='epoch',
    save_steps=1,
    metric_for_best_model='accuracy',
    per_device_train_batch_size=256,
    num_train_epochs=3,
    seed=GLOBAL_SEED,
    weight_decay=0.2
)

# TODO: Set the argumetns 
trainer = Trainer(
    model_init=model_init,
    args=training_args,
    train_dataset=datasets_dict['train'],
    compute_metrics=compute_metrics,
)
# end of TODO

trainer.train()

eval_en_result = trainer.evaluate(datasets_dict['en_test'])
eval_it_result = trainer.evaluate(datasets_dict['it_test'])
eval_fa_result = trainer.evaluate(datasets_dict['fa_test'])

print(f"MODEL: {model_name}")
print(f"EN: Acc: {eval_en_result['eval_accuracy']}, MRR: {eval_en_result['eval_mrr']}")
print(f"IT: Acc: {eval_it_result['eval_accuracy']}, MRR: {eval_it_result['eval_mrr']}")
print(f"FA: Acc: {eval_fa_result['eval_accuracy']}, MRR: {eval_fa_result['eval_mrr']}")
print(f"OVERAL: Acc: {(eval_en_result['eval_accuracy']+eval_it_result['eval_accuracy']+eval_fa_result['eval_accuracy'])/3}, MRR: {(eval_en_result['eval_mrr']+eval_it_result['eval_mrr']+eval_fa_result['eval_mrr'])/3}")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:407: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Could not estimate the number of tokens of the input, floating-point operations will not be computed
#     <div>
#
#       <progress value='6' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6/6 00:10, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2</td>
#       <td>1.301500</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.060500</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.960400</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='24' max='8' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [8/8 00:01]
#     </div>
# MODEL: RAltCLIP_CE_12_T
# EN: Acc: 0.578125, MRR: 0.7354724702380954
# IT: Acc: 0.28125, MRR: 0.4773809523809523
# FA: Acc: 0.09375, MRR: 0.3039682539682539
# OVERAL: Acc: 0.3177083333333333, MRR: 0.5056072255291005
